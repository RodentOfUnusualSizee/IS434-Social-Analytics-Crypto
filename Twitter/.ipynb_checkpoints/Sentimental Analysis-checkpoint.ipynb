# %%
import pandas as pd

# %%
df = pd.read_excel("AAVETweetsSep21Mar22.xlsx", sheet_name="WorkingCopy")

# %% [markdown]
# Checklist: Sushi, AAVE

# %%
df.head()
# Out:
#        Date                   ID  \
# 0  5/3/2022  1500256508852183042
# 1  5/3/2022  1500253319822028801
# 2  5/3/2022  1500252613677309960
# 3  5/3/2022  1500252380084191233
# 4  5/3/2022  1500252224802508802
#
#                                              Content         Username
# 0  Swing ðŸš¥  $FLOW ðŸŸ¡ $5.83 $WAVES ðŸŸ¡ $17.0...       quant_coin
# 1  @apyfinance All of the folks in this chat are ...  MarkJoh16435560
# 2  7/19 âž¡ï¸ Why is this so important for the @...     daic_capital
# 3  Aave $AAVE Price IDR: Rp 1,797,656 Price USD: ...          GetCuan
# 4  $AAVE  Was looking for a breakout, but looks w...   Tao_Of_Trading

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106054 entries, 0 to 106053
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Date      106054 non-null  object
#  1   ID        106054 non-null  int64
#  2   Content   106054 non-null  object
#  3   Username  106054 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 3.2+ MB

# %%
# Preparing Text Data for Sentimental Analysis

import numpy as np
import re
from nltk.corpus import stopwords

stop = stopwords.words('english')

def clean_content(contentInput):
    if type(contentInput) == np.float:
        return ""
    contentInput = contentInput.lower()
    contentInput = re.sub("'", "", contentInput) # to avoid removing contractions in english
    contentInput = re.sub("@[A-Za-z0-9_]+","", contentInput)
    contentInput = re.sub("#[A-Za-z0-9_]+","", contentInput)
    contentInput = re.sub(r'http\S+', '', contentInput)
    contentInput = re.sub('[()!?]', ' ', contentInput)
    contentInput = re.sub('\[.*?\]',' ', contentInput)
    contentInput = re.sub("[^a-z0-9]"," ", contentInput)
    contentInput = contentInput.strip()
    contentInput = contentInput.split()
    contentInput = [w for w in contentInput if not w in stop]
    contentInput = " ".join(word for word in contentInput)
    return contentInput

# %%
#spliting data into months as for time series sentimental analysis
#Geting start and end date of data
monthList = pd.date_range('2021-09-01','2022-03-06', 
            freq='MS').strftime("%m/%Y").tolist()

#creating blank dict for later

timeSplitData={}
timeSplitDataSentiment = {}

for month in monthList: 
    timeSplitData[month] = []
    timeSplitDataSentiment[month] = []

# %%
for row in df.iterrows():
    #extracting month data from row
    dateData = row[1]['Date']
    tmp = dateData.find('/')
    monthData = dateData[tmp+1:] #removing day e.g '12/'
    if len(monthData) == 6:
        monthData = "0"+monthData
    
    if monthData in timeSplitData: # check if data is in range of date we want to analyse
        content = row[1]['Content']
        #cleaning Data
        cleaned = clean_content(content)
        #Storing into time split dict
        timeSplitData[monthData].append(cleaned)
# Out:
# C:\Users\yanwe\AppData\Local\Temp/ipykernel_16768/2198407358.py:10: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(contentInput) == np.float:

# %%
timeSplitData
# Out:
# {'09/2021': ['2021 09 30 13 00 gmt aave net cap flow 4m price change 0 3 last 24 hrs aave',
#   'long sol aave yfi',
#   'top 3 dao tokens market capitalization according order 1 uni 2 aave 3 makr',
#   'know defi sentiment bottomed doesnt drive material price increase aave mkr comp',
#   'good job make sure add segment confidential defi confidential assets also',
#   'uniswap v2 dai eth lp token collateral create maker new vault combo sushi audio sol bal dydx aave',
#   'badass',
#   'combo sushi audio sol bal dydx aave',
#   'avalanche foundation announces 180 million defi incentive program provide native token liquidity mining incentives users period 3 months aave 20 million avax curve allocated 7 million avax',
#   'lo que dice juan es muy cierto recuerdo por ejemplo cuando el pasado hab pr cticamente plataformas lo estaba por nombrar algunas hoy hay miles de plataformas en muchas varios',
#   'aave q4',
#   'exception rule though think 2024 well see many types distributing profits without second thought already baked roadmaps non us based daos like coops daos',
#   'best time plant tree 20 years ago second best time time luna matic avax uni link fil atom ftt xtz urus doge asx egld aave ksm comp amp eth rune btc bnt',
#   'sure would weird think maker holders would prefer profit sharing token burning seems awkward seemingly less legally charged alternative profit sharing many companies constant stock buybacks versus distributing dividends',
#   'depends institution allowed regulators participate explicitly barred using defi current state least options available work beauty defi every flavor coexist',
#   'platforms profitable might share revenue yet 1 waiting cross invisible line decentralized security even sec land 2 theyve decided best wait tenure lawyer gensler',
#   'looking potential ecosystem suits need near aave mkr inj inch fin ont link band math grt oin bal dodo',
#   'rly move towards 70 btc eth mkr aave comp uni link xrp doge icp ect snx sol mln qnt farm yfi forth storj fil mana enj ogn bal nmr fet ach amp ankr zrx ren lrc skl celo rlc gtc matic grt ctsi nkn keep nu dnt cvc uma',
#   'never boring day defi',
#   'rly pounding table cheap btc eth mkr aave comp uni link xrp doge icp ect snx sol mln nkn storj fil mana enj ogn bal nmr fet ach amp ankr zrx ren lrc skl celo ctsi keep nu dnt cvc uma',
#   'many worse targets space still holding aave',
#   'another thought buying nfts crypto borrowed using og nfts collateral add new nfts borrow crypto simple',
#   'sparta bnb 1d sparta btc bnb ada xlm trx doge hot gto drep ncash mkr aave wing eth xvs uni cake dot xvs kava vtho win tct luna stmx dego iotx alice farm celr win dent hot rvn orn eth axs celr iota elf',
#   'bom projeto',
#   'hits 1 first please retweet btc eth mkr aave comp uni link xrp doge icp ect snx sol mln nkn storj fil mana enj ogn bal nmr fet ach amp ankr zrx ren lrc skl celo rlc gtc matic',
#   'yes like go gnu closed source according like breaking rules metaverse still understand choice',
#   'source source credit byron gillam',
#   'supposed last week feeling like kid wating new game drop defi fun bro',
#   'swing theta 5 01 trx 0 08896 xmr 250 9 cake 18 92 eos 3 91 xtz 5 89 aave 275 3 axs 73 32 atom 35 84 ftt 51 5 go',
#   'bom projeto',
#   'anytime soon thing supposed launch today right still couple hours xd',
#   'cake brainer course others hopeful plays passive income farms trava sweeten deal means sit back relax enjoy ride passive income boring side',
#   'got tomorrow right',
#   'week shaq oneil tweeter visa tik tok fed sec talking cryptoverse mega bullish xrp btc eth link dot dia theta vet aave comp',
#   'mainnet sirs im playing like kid testnet like real money please sir im addicted help',
#   'hope everyone fantastic productive day avax officially boofi already 10x reaper launchpad allocation aave imminent lfg',
#   'bom projeto',
#   'many good selections gonna fun end year',
#   'jerome powell said bitcoin ada sol eth algo atom uni aave matic dot enj link xlm btc',
#   'bom projeto',
#   '2021 09 30 13 00 gmt aave price change 0 3 total trading volume 323 550aave last 24 hrs aave',
#   'bom projeto',
#   '2021 09 30 13 00 gmt aave net cap flow 4m price change 0 3 last 24 hrs aave',
#   'best discord group 80k members success rate join server ada matic skl sushi ankr crv storj inch enj nkn ogn ctsi mir sol rlc trb aave',
#   'welcome discord group crypto traders ont uni aave comp mkr crv mdx cake banana snx pickle value df wing fuel link lit sushi coti',
#   'point conversation took left turn stani attempting enforce puritanical dress code top fictitious characters',
#   'urus finally noticed market cap still 41m vs aave market cap 3 6b comp market cap 1 7b urus easily still go 25 x year max supply 1m partnership announcements soon thank later',
#   '2 aave lending never matured probably abandoned agave xdai live yet exact talk aave cc last week wait',
#   'week something huge coming loading largest incentive program 200m got better hope coming appetite available week avax',
#   'dont miss next move hours trx eos shib aave cro bsv algo mkr fil luna ftt xtz btcb cake klay amp atom neo leo miota tfuel avax xmr chat r00m details b 0',
#   'less hype returns skl setup 2x check reversal link btc eth nu algo grt mana skl band cvc dnt fil dash knc bnb oxt bat doge aave xtz xlm xrp zrx ada sushi enj ada matic',
#   'award goes master ghosts team fully metaverse cool black tie show',
#   'new margin trading module added set v2 system module allows set developers build leverage products managers trade leverage utilizing aave base protocol documentation',
#   'greatest innovations crypto space coming defi properly exposed eth link luna aave sushi',
#   'aave approved avax possibly 100',
#   'swing theta 4 98 trx 0 08845 xmr 252 7 cake 18 75 eos 3 88 xtz 5 84 aave 272 9 axs 72 88 atom 35 78 ftt 51 04 go',
#   'keep eye bmi purchase provide coverage stablecoins exchanges smart contracts bunch coverage pools like v2 app coming october dao take soon link',
#   'current positions axs ftm luna alice dot ksm aave fet aelf poly sol',
#   'build linux choose whether runs kid machine india microsoft data center believe software ie free speech every user need able decide configuration wish use software',
#   'friendly reminder quiet fears bnb btc btg ftt link rune urus dot atom aave comp sol ada eth',
#   'aave 1d',
#   'loves plgr love uni aave plgr',
#   'ticket bed',
#   'lied avax aave',
#   '09 30 21 update net assets management holdings per share market price per share investment products total aum 38 7 billion btc bat bch link mana eth etc fil zen ltc lpt xlm zec uni aave comp crv mkr sushi snx yfi uma bnt ada',
#   'ignorant like us space go see beyond greedy bigger picture complete financial surveillance system tiny set rules privacy anonymity trustlessness permissionlessness important',
#   'rt introducing greenwood router borrow crypto lowest rate defi added gas costs supported protocols soon cream fuse kashi try greenwood router today',
#   'nftt sure fact could easily 100x within next year liquid nft marketplace commission free zero minting fees one click minting kava ampl cvp wan aave musd yfi unfi',
#   '2021 09 30 13 00 gmt aave price change 0 3 total trading volume 323 550aave last 24 hrs aave',
#   '',
#   'good bye old friends btc eth ren wan link aave algo utk',
#   'project looking really good',
#   'anyone curious space tutorials great place start eth uni aave ndx',
#   'cryptocurrencies yield btc eth chsb usdc bnb xrp usdt matic paxg enj aave knc dai comp ren utk uni chz grt bat crv link dot ftt soon amp download',
#   '2021 09 30 13 00 gmt aave total trading volume 323 550aave net cap flow 4m last 24 hrs aave',
#   'nord 8 hours go huge massive pump guys dont late gonna amazing btc eth dot trias poodle ada link neo kick kava kick doge bnb bch sol ltc matic fil trx luna aave xmr eos dot maha doge sol bch shib',
#   'luna mir anc ust btc rune atom ocean cake shib bnb axs matic link mine egld enj aave lota spec avax',
#   'swing theta 4 99 trx 0 08879 xmr 251 cake 18 78 eos 3 89 xtz 5 84 aave 273 4 axs 72 81 atom 35 06 ftt 51 39 go',
#   'cool',
#   'short aave aaveeth patr n detectado rotura de soporte diario nivel',
#   '',
#   'luna mir anc ust btc rune atom ocean cake shib bnb axs matic link mine egld enj aave lota spec avax',
#   'silly',
#   'week daos september 30 2021 featured news arc bid makes crowfund tool open public compound bug weekly dao stats boardroom read',
#   '2021 09 30 13 00 gmt aave net cap flow 4m price change 0 3 last 24 hrs aave',
#   'see mutually exclusive tradfi inefficient archaic system using old tech layers rent seekers aave becomes tradfi introduce separate permissioned pool kyc',
#   'yes',
#   'aave went 44 correction since summer peak falling wedge daily chart screaming breakout rsi divergences tfs lend know familiar massive moves gonna take soon btc',
#   'told grandma could use aave avax im starting think delays may see life time',
#   '2021 09 30 13 00 gmt aave net cap flow 4m price change 0 3 last 24 hrs aave',
#   'mmoonnnnn',
#   'amazing chainge finance chng fsn avax',
#   'btc eth trx dot ada sol xrp aave bsc urus luna egld sfi algo bsc bnb',
#   'aave xvs mkr',
#   'powerfull everychain liquid avax thanks crosschain roaming chainge finances',
#   'luna mir anc ust btc rune atom ocean cake shib bnb axs matic link mine egld enj aave lota spec avax',
#   'yearn fees also shared yfi holders',
#   'moon available chainge finance fantastic',
#   'xvs qi looking jump back aave launch avalanche shout qbt',
#   'avax chng fsn',
#   'yep',
#   'see moving 2nd largest tvl chain coming weeks months 700 million incentives major defi protocols aave crv sushi many launching sub second finality low fees full evm compatibility avax',
#   'dont miss next move hours trx eos shib aave cro bsv algo mkr fil luna ftt xtz btcb cake klay amp atom neo leo miota tfuel avax xmr chat r00m details b 0',
#   '2021 09 30 13 00 gmt aave total trading volume 323 550aave net cap flow 4m last 24 hrs aave',
#   'thoughts dydx volumes growing 50x weekly active trader growth 5x possible gaming trading rewards program',
#   'also bar today everyone speaking profitability spell',
#   'luna mir anc ust btc rune atom ocean cake shib bnb axs matic link mine egld enj aave lota spec avax',
#   'swing theta 5 03 trx 0 08939 xmr 251 9 cake 18 89 eos 3 93 xtz 5 89 aave 275 8 axs 73 45 atom 34 64 ftt 51 75 go',
#   'egld orn aave link',
#   'signal aave btc sell volume 2 03 btc price 0 69 0 00629500 btc last 1h bought 3 03 btc sold 2 69 btc last 24h bought 39 92 btc sold 27 16 btc last 7d bought 445 25 btc sold 435 98 btc',
#   'sure',
#   '1 defi start financing real world assets kyced parties legal frameworks important protect investors doesnt mean needs permissioned centralized way meaning single party controlling',
#   'market current trend dn defi performance 7 day weak 30 day weak 90 day weak market aave looks bad dollar cost averaging',
#   'eth get explosive x1000 coming aave sushi fil comp mkr dydx ldo joe mana maid uma neo eth luna alice rsr celr one ankr etc trx eos xrp bch btc eth btt alpha ont',
#   'yearn gets revenue dumping crv',
#   '2021 09 30 13 00 gmt aave price change 0 3 net cap flow 4m last 24 hrs aave',
#   '2021 09 30 13 00 gmt aave price change 0 3 net cap flow 4m last 24 hrs aave',
#   'reason took lion share china ban',
#   'sell aave price 273 target 272 change 0 59 trading test 141',
#   'convex finance makes 600m year valued 1 15th dydx market clearly sleeping giant',
#   'good bye old friends btc eth ren wan link aave algo utk',
#   'hate song feel like wen aave',
#   'skl watching possible breakout btc eth mkr aave comp uni link xrp doge icp ect snx sol mln qnt farm yfi forth storj fil mana enj ogn bal nmr fet ach amp ankr zrx ren lrc skl celo nu rlc gtc matic',
#   'aave b yle pattern g r nce akl atilla bey geliyor hur z bunlar adam zorla zengin eder',
#   'got covered 8th chain available cross chain roaming future dex grow big like elephant',
#   'woo usdt target 3 hit 40 spot taking profits doge eth btc ltc fil bnb rsr band link comp dot trb uni aave sxp sol cake sushi xrp alice xvs dot join us free telegram',
#   'revenue though',
#   'true defi freedom app powered unique blockchain technology including worlds secure amp advanced dex spot futures options ios android',
#   'agree give time tell us thursday thursday',
#   'tell people farm postponed like 1 min starts think',
#   'trade bit higher possible 10 upside aave sand keep crv fet qnt bal',
#   'swing theta 4 99 trx 0 08884 xmr 249 2 cake 18 78 eos 3 89 xtz 5 82 aave 272 9 axs 73 24 atom 34 33 ftt 51 34 go',
#   'chng big project',
#   'quick told yall gonna huge add btc eth mkr aave comp uni link xrp doge icp ect snx sol mln qnt farm yfi forth storj fil mana enj ogn bal nmr fet ach amp ankr zrx ren lrc skl celo',
#   'still 2 hours told thursday coming today',
#   '5 months cvx revenue annualized approximately 360m presenting incomplete data makes questions thoroughness data products',
#   'rly level run 98 load zone btc eth mkr aave comp uni link xrp doge icp ect snx sol mln qnt farm yfi forth storj fil mana enj ogn bal nmr fet ach amp ankr zrx ren lrc skl celo',
#   'maximalism leads opportunity minimalism golden one',
#   'wen amp wen rush',
#   'great meet team behind risk dao proposal',
#   'luna mir anc ust btc rune atom ocean cake shib bnb axs matic link mine egld enj aave lota spec avax',
#   'great',
#   'nu link sushi yfi sol aave ltc ankr knc kava xem band ren zec nav btc ada srm zen xrp xlm eth theta zil inj bzrx rune crv coti ftm dia ava bnb ksm',
#   'udo frighteningly cheap right people recognize buy 100x never changes like sol matic avax bnb axs eth btc luna qnt vxv chz aave',
#   'v3',
#   'full overview columbus 5 new apps increased staking rewards nfts via luna mir anc ust btc rune atom ocean cake shib bnb axs matic link mine egld enj aave lota spec avax',
#   'aave mix',
#   'looks like partnership win win',
#   'really hope yall listened loaded rly btc eth mkr aave comp uni link xrp doge icp ect snx sol mln nkn storj fil mana enj ogn bal nmr fet ach amp ankr zrx ren lrc skl celo rlc gtc matic',
#   '',
#   'fees going confused',
#   'swing theta 5 00 trx 0 08865 xmr 248 5 cake 18 57 eos 3 88 xtz 5 79 aave 272 1 axs 72 9 atom 33 84 ftt 50 85 go',
#   '',
#   'company dydx token holders',
#   'woo',
#   '',
#   'fomo',
#   'love chng thanks everything',
#   'advanced secured wallet ever lot cool facilities earn passive income without hassle every crypto user try atleast one time im 100 confident making try fall love chainge moon',
#   'please meet',
#   'joe coming spot',
#   'graph shows revenue protocol uniswap lps charge fees protocol',
#   'sell aave 273 04 0 79',
#   '19 projects hold right kda kadena omi ecomi mello mello sol obviously aave think great potential honestly huge gainers',
#   'yeah dydx revenue goes company pockets token holders',
#   '1 paladin lending live go stake uni comp aave stkaave juicy yield',
#   'reminder following happened past week alone defi gt launching aave arc walled garden version platform gt requiring users sign legal message chain gt raised 80m jpm ubs build defi infrastructure',
#   '',
#   'uniswap',
#   '',
#   'leaving eth eth btc atom snx aave uni sushi link ltc cake bnb trx btt xrp ada',
#   'tho reason listed even tho would first list',
#   'algo btc eth xrp ada bnb usdt dot uni doge usdc sol bch luna link ltc icp matic algo xlm etc fil avax aave eos xmr dash shib yldy xps exit comp nu',
#   'according social media buzz silver spoon star also instrumental saving btc crypto doge aave etc ada matic dgb mana eth btc bnb bch comp enj link kcs uni vet storj zen algo paxg waves rvn',
#   'ryan would first one list please take look cvx',
#   'top projects 2nd half time page 1 5 next page comes tomorrow btc bnb uni matiq aave cos chz snx enj zil near hnt eth dot link vet ksm rune',
#   'agree hope dont restrict users enjoying flavor force play world maintain advantage',
#   'arrancamos long en aave',
#   'massive miss leaving bias guess',
#   'facts ada dot sol eth avax algo luna bnb atom eos xtz matic ksm trx cake snx near waves aave skl sushi dash dcr xprt ftm egld band zil icx one xem crv rune akt dfi',
#   'introducing greenwood router borrow crypto lowest rate defi added gas costs supported protocols soon cream fuse kashi try greenwood router today',
#   'garbage list convex finance 50m monthly revenue 600m annualised mention 250m mcap coin get wealth available',
#   'yep another big protocol missing list rather stay radar big stop good accumulation undervalued gov tokens',
#   'dont miss next move hours trx eos shib aave cro bsv algo mkr fil luna ftt xtz btcb cake klay amp atom neo leo miota tfuel avax xmr chat r00m details b 0',
#   'help man put ohm map ppl yet discover power 3 3',
#   'link chart',
#   'also missing gt 15m revenue since launch 7 months ago distributed lqty stakers',
#   'gro aims provide yield stablecoins tranches risk yield like chess generating income lending aave compound trading fees sushi uni protocol incentives crv cvx backers including 3ac stani k robert l kain w',
#   'aave decreased 3 59 9 9 hour price 270 30000000 usdt 16 30 56 utc',
#   'aave price 271 03 change 1 97 performing market context market currently bullish',
#   'arent sharing',
#   'finally track polygon dont forget add pearzap',
#   '',
#   'aave buy recommendation price charts show settling price rising one hodl 4',
#   'swing theta 4 97 trx 0 08825 xmr 246 1 cake 18 6 eos 3 87 xtz 5 76 aave 271 6 axs 73 4 atom 33 96 ftt 50 48 go',
#   'metaverse indifferent spot everyone invited join equals among equals extra sauce frontend whatever',
#   'buy aave 270 911',
#   'tokens always interesting follow sector tell us lot broader market lets analyze charts uni link aave see top defi tokens could headed next',
#   'revenue going',
#   'algo btc eth xrp doge ada matic sol xlm dot link uni sushi yldy xlm qnt ltc bch bnb xmr dash hbar comp aave zrx aapl ms nvda vet avax nu',
#   '2021 09 28 15 00 gmt aave price change 0 9 total trading volume 362 097aave last 24 hrs aave',
#   'like focusing growing taking advantage avalanche native capabilities e g subnets keep relevant even big boys come online native projects offer similar services im hodling qi',
#   'created academy tutorials basic things beginner needs know start defi journey defi use trade lend amp borrow buy defi index',
#   'unsurprisingly 4 top 5 defi apps lending apps currently lead 13 75b locked',
#   'give revenue back token holders',
#   '',
#   'full batch risk parameter updates dashboard back',
#   '4 xsushi tokens vested passive investing amp used collateral lending amp borrowing amp flash loans adds even features xsushi',
#   'top trending tokens projects highest trading volume last 24h tomi dgold pbrew mcash ghst aave brew dino',
#   'uni',
#   '2021 09 28 15 00 gmt aave net cap flow 2m price change 0 9 last 24 hrs aave',
#   'aave',
#   'avax got aave amp play',
#   'luna mir anc ust btc rune atom ocean cake shib bnb axs matic link mine egld enj aave lota spec avax',
#   'im sure think aave arc tbh lets see goes keep open mind one grand experiment anyway',
#   'jar go crazy x millions grab bag partenered req aave icp ckb one theta matic crypto doge waves busd ada bnb matic ltc vet busd buni icx shib egld',
#   'picked seems like something missing',
#   'best knowledge aave comp uni sharing revenue well lps mms dydx receiving incentives',
#   'super useful ct sees 96 dumps pumps advance luna doge slam nft pte dot arte cava usdc xem jind aer bsp aave xtz bnb bch xhv mana lba shib rune cel ht arnx usdt bone btc yfi egld dai dash comp',
#   'dont understand bend rules',
#   '2021 09 28 15 00 gmt aave net cap flow 2m price change 0 9 last 24 hrs aave',
#   'available',
#   'excuse isnt good dydx price fee paid holders value accrue token directly',
#   'top 5 mentions updated every 15 minutes except btc eth 1 comp 686715 point 2 aave 617789 point 3 mkr 594091 point 4 sol 424832 point 5 cake 310359 point',
#   'aave making bullish gartley pattern 1d chart marked sl entry tps according fibonacci retracements official call analysis dyor aave',
#   'available sweetest defi portfolio manager start tracking polygon assets',
#   'one important legos lending platform using aave mkr comp xvs spell qi tru cream anc',
#   '4 dapps currently generating fees diss btc bullish reminder defi whole early uni aave sushi comp',
#   'sell aave 274 727 1 34',
#   'swing theta 5 02 trx 0 08862 xmr 247 5 cake 18 78 eos 3 89 xtz 5 85 aave 274 8 axs 75 28 atom 34 17 ftt 51 11 go',
#   'soon regret enough eth ethusd btc pols ada doge nano bnb link flow xrp dgb coti xvg tvk bondly polk cvr dot ksm ocean utk atom dia rsr xlm yfi aave eos neo icx memos yuy rune',
#   'dont miss next move hours trx eos shib aave cro bsv algo mkr fil luna ftt xtz btcb cake klay amp atom neo leo miota tfuel avax xmr chat r00m details b 0',
#   'kyc surveillance locking oceans folks platforms cannot see abuse come already lost bigger projects set stage system control potential keep humanity control tiny 4ever',
#   'uniswap generates 0 revenue protocol uni holders since trading fees go lps',
#   'think forgot protocol cast eyes',
#   'meanwhile yet ship anything arbitrum avax',
#   'keep sleeping olympus lol ohm',
#   'polygon flavourite',
#   '',
#   '',
#   'assuming thats something governance change',
#   'unsure uniswap list',
#   'steth match made citadel',
#   'thank pointing also appreciated another person indicated yearn chart got revs w incentives',
#   'luna mir anc ust btc rune atom ocean cake shib bnb axs matic link mine egld enj aave lota spec avax',
#   'buy aave 271 1',
#   '2021 09 28 15 00 gmt aave net cap flow 2m price change 0 9 last 24 hrs aave',
#   'think think hapoen aave amp crv launch one dot aave comp sushi vet jup vxv qnt ksm sol eth ada xrp shib uni hex avax utk atom link joe xrp',
#   'sell aave price 274 target 273 change 0 46 trading test 142',
#   'crypto traders want one thing disgusting link aave utk wan sol ksm dot',
#   'dont top fomo buyer matic sol doge eth one algo ftt avax aave smart buy bottom',
#   'poll bigger',
#   'sounds good',
#   'light xmr btcx tnxp dsgt xbi busd expr cvc itrm nmr vet dcr hpnn oxt bb starl ht mln yayo hoge wimi mck gtc chow tawnf skl aave hyln dogira mth spaq xdc',
#   'dont forget part ogs twitter account sold soul sell centralized shitcoins top matic sol doge eth one algo ftt instant unfollow every time someone show chart 54000 pump like aave',
#   '',
#   '23 e coin recommendations 2021 09 30 well analyze aave matic xtz sushi got hit hard last dip bargains 1',
#   'swing theta 4 99 trx 0 08801 xmr 245 9 cake 18 71 eos 3 86 xtz 5 81 aave 272 8 axs 74 83 atom 34 24 ftt 50 66 go',
#   'uniswap',
#   'super important distinction',
#   'guess still keep buying ohm',
#   'one note unlike protocols list dydx fees go directly company protocol dao lps',
#   'bought orion 65 cents hodl price goes past aave comp current price mark retire lol',
#   'prq parsiq announced pretty cool things besides iq protocol alts defi dot ltc eth bnb btc om rfuel ksm gvt sky xvg trx rsr link ada eos aave neo zil comp icx sol tomo kai pols maha',
#   'pro fire blocks right',
#   'btc obvious godzilla pattern btc eth ada bnb xrp dot ltc link xlm doge uni aave eos atom trx trx avax vet xmr btc',
#   '5 dai stablecoins directly lend anyone achieve strong peg swaps fees good stablecoin par better say goodbye stablecoins par value',
#   'bullish bearish patterns cryptocurrencies btc eth bnb ada usdt doge xrp dot icp bch ltc uni link usdc xlm vet sol etc eos theta wbtc trx fil shib busd xmr aave neo matic pax nft hodl',
#   'new bridger drop leading native avax dex swap trade assets example weth usdt joe aave check pools juicy farms rush upon us gb',
#   'avax mine',
#   'youre defi maxi',
#   'wen',
#   'wen aavalanche sir',
#   'another avax event books without aave launch',
#   'selling setting infrastructure serve capitalize huge segment market nothing wrong like use sell tokens',
#   'hola dictador hodllllll doge trx xmr eos ltc dash ada mxt wax tlm aether usdt busd bnb aave waves chia cesc dcr xrp xlm via matic btt bch enj aapl dot uni link sol sps dec',
#   'vui ng th ng b v vi c ni n p v r ti n 30 th ng 9 l c 1 00 ng gi utc giao ch 30 th ng 9 l c 1 00 chi u utc th ng tin chi ti',
#   'crypto markets mature information asymmetry decreases token performance based long term strategy growth execution less less dreams ideology find winners',
#   'ryan love work case though dont think dydx revenue annualized solely past month lots dex volume coming china ban diminish overtime',
#   'wbtc btc wbtc btc aave usdt grt usdt comp usdt 30 1 00 30 1 00 p utc',
#   'uni ser',
#   'wbtc btc wbtc btc aave usdt grt usdt comp usdt lem ifti alt nda listelenece ini duyurmaktan memnuniyet duyuyor para yat rma ekme lm r ticaret lm r',
#   'dont miss next move hours trx eos shib aave cro bsv algo mkr fil luna ftt xtz btcb cake klay amp atom neo leo miota tfuel avax xmr chat r00m details b 0',
#   'banana sushi keeping watching space',
#   'developments clear negative creating institutional product welcome innovation along multi chain functionality shows aave adapt grow thrive rapidly evolving landscape',
#   'trader joe big leagues',
#   'imagine look everyone face day coinmetrics whatever data source using adds first time would literally fall right maker amp perp cool 45m annual revenue',
#   'hmmmm decide aave starting become hope make money decentralize',
#   'excellent see moving decentralised direction community members contributing aaves success im expecting onboarding collateral across various platforms become streamlined dedicated dao supporting process',
#   'agreed also challenge imo fairest way compare revenue would olympus pro fees treasury owned liquidity pool fees interest treasury assets',
#   'uniswap list',
#   'think call sold going defi cefi kyc surveillance future working towards',
#   'horrible takes',
#   'lol taking dydx hype calculate annualized revenue',
#   'see people linked dune dash already let know help',
#   'undervalued',
#   'ser',
#   'also like visit coffee shop hear',
#   'made excellent stuff',
#   'wish data olympus dao last checked would top 5 revenue generated liquidity pools alone',
#   '1 today aave launch 2 launch joe banker 4oct unfortunantly lost frist mover advantage money market tvl go safer aave degen banker qi good farming buying yet',
#   'happened uniswap',
#   'token holders get none',
#   'sept 30 2021 old veterans attack feat',
#   'luna aped lets send pls luna eth btc ada ltc luna aave avax bnb',
#   'end 2021 22 goals 10 yfi 25 btc 50 aave 250 eth 2 5m stables 500 alcx 2500 dot 2500 sol 25k kda 50k ftm 100k ada',
#   'price performance top defi market cap erc 20 1 link 2 aave 3 amp 4 mkr 5 comp 6 snx 7 ttt stay updated',
#   'community clear onboarding institutions 89 67 votes favor others find bad precedent aave 275 66 1 13',
#   'permissioned simply gateway permissionless says founder adding whitelister',
#   'swing theta 5 03 trx 0 08835 xmr 246 9 cake 18 68 eos 3 88 xtz 5 93 aave 275 8 axs 76 15 atom 34 47 ftt 51 15 go',
#   'really wait avax launch aave please stop suffering',
#   'prq parsiq announced pretty cool things besides iq protocol alts defi dot ltc eth bnb btc om rfuel ksm gvt sky xvg trx rsr link ada eos aave neo zil comp icx sol tomo kai pols maha',
#   'new listing coin aave pairs',
#   'dont miss next move hours trx eos shib aave cro bsv algo mkr fil luna ftt xtz btcb cake klay amp atom neo leo miota tfuel avax xmr chat r00m details b 0',
#   'news coming upcoming product service releases forgotten mobile app blows mind project 16 cents 16k holders breaks oh boy ersdl link bnt eth btc doge ilv aave avax axia',
#   'nice project',
#   'yes',
#   'doorsteps promised today aave launch rewards thought id gather thoughts might best position avax native portfolio take full advantage 3 19',
#   'day results show mixed bag analysis correct buy neither mir aave oh well',
#   'comp ralley hard ent news payment rewards btc eth mkr aave comp uni link xrp doge icp ect snx sol mln qnt farm yfi forth storj fil mana enj ogn bal nmr fet ach amp ankr zrx ren lrc skl celo poly xyo rly iotx btrst',
#   'listen back',
#   'planning put snapshot tomorrow allowing time comments submit chain assuming aave holders favor poll still need 1 additional signer risk dao multisig reach youre interested help',
#   'risk dao proposal taking shape proposed budget payout mechanism initial list contributors aave forum feel free comment share feedback',
#   'could wish local aave coffee shop',
#   'bugs aave keep stacking keep staking',
#   'jar x1000 coming fast jar moon aave sushi fil comp mkr dydx ldo joe mana maid uma neo eth luna alice rsr celr one ankr etc trx eos xrp bch btc eth btt alpha ont',
#   'swing theta 5 02 trx 0 08806 xmr 247 8 cake 18 67 eos 3 87 xtz 5 92 aave 273 3 axs 75 75 atom 34 69 ftt 51 07 go',
#   'hey looking new incentives sheet one field marked tba 78m tel rewards distributed guess throughout code pools pools let see right',
#   'added aave comp sol think see big turn market charts indicators help paint picture end best guess',
#   'agreed',
#   'completely agree barn bridge etc also benefit daos put overflowing treasuries productive use dao investing provide huge boost defi 2021 22 dont think investors aware likely happen space',
#   'play altcoins betfury house games sportbook mine bfg tokens receive dividends cashback many altcoins accepted comp aave link usdc matic plenty others play betfury',
#   'aave patiently waiting tap',
#   'whales buying aave last price 0 00631100 binance alerts last 7 days 3 btc',
#   'think still place daos like well secure professional level financial services great ui',
#   'lfg steth would collateral discounted stable borrowing gainz',
#   'daos begin invest large treasuries solutions like think well see consolidation top etc big winners risk management prefer proven investment options upstarts',
#   'updated proposal list lidos steth lending borrowing published please share feedback support',
#   'man load shit comp way undervalued btc eth mkr aave comp uni link xrp doge icp ect snx sol mln nkn storj fil mana enj ogn bal nmr fet ach amp ankr zrx ren lrc skl celo nu poly req rly cvc dnt uma',
#   'omg much resistance ahead varna dex quasar fast exits month next btc etc people say omg btc eth xrp dot ada ltc bnb xlm uni aave doge snx eos mkr atom xtz comp sushi sol uma dai luna zrx',
#   'soon regret enough eth ethusd btc pols ada doge nano bnb link flow xrp dgb coti xvg tvk bondly polk cvr dot ksm ocean utk atom dia rsr xlm yfi aave eos neo icx rune',
#   '',
#   'agree',
#   'ctk aave eos h2 nuestras se ales ser n visibles en su cuenta de tradingview al crear sus alertas puede ser notificado por correo electr nico sms de las se ales de compra venta proporcionadas por nuestro algoritmo',
#   'ctk aave eos h2 nos signaux seront visibles sur votre compte tradingview en cr ant vos alertes vous pourrez tre pr venus par mail ou sms des signaux achat ou de ventes donn par notre algorithme',
#   'might good question direct given aave arc compound treasury products id prefer institutional defi permissioned negative connotation community',
#   'honestly dont see life future without one best inventions time projects like set us free banks oin mnt aave',
#   'launching social media plattform could absolute gamechanger largest lending protocol arguably decentralized defi player steps social media market aave',
#   'dont miss next move hours trx eos shib aave cro bsv algo mkr fil luna ftt xtz btcb cake klay amp atom neo leo miota tfuel avax xmr chat r00m details b 0',
#   'swing theta 4 98 trx 0 08743 xmr 246 6 cake 18 59 eos 3 84 xtz 5 93 aave 272 2 axs 76 96 atom 34 12 ftt 50 74 go',
#   'largest defi incentive program 200m got better hope coming appetite available week avax aave curve',
#   'comp still 12 following slight immediately seen threatened user 296 62nd largest mc rn 5 5 mil tokens supply advice aave amp comp produced ridiculous returns bought 300',
#   'bonjour tu pourras montrer comment tu fais merci davance quelle que soit ta r ponse',
#   '4 great parties',
#   'true beyond party raave seen much formal list somewhere',
#   'rly adding 73 75 btc eth mkr aave comp uni link xrp doge icp ect snx sol mln nkn storj fil mana enj ogn bal nmr fet ach amp ankr zrx ren lrc skl celo rlc gtc matic grt iotx xyo',
#   'listen patient final day september ask wen aave',
#   'first sounds like super power problem also cpap generally used treat sleep apnea youre snoring decide want spend lot money cpap device',
#   '',
#   'dont forget starting today 3 pm utc trava w 1 2 liquidity mining cake xrp ada aave',
#   'sell aave price 273 target 271 change 0 61 trading test 152',
#   'selling aave',
#   'clv dot conviced pushed load btc eth mkr aave comp uni link xrp doge icp ect snx sol mln qnt farm yfi forth storj fil mana enj ogn bal nmr fet',
#   'ascendex w 9 30 1 00 utc 9 30 1 00 p utc wbtc btc wbtc btc aave usdt grt usdt comp usdt',
#   'reasons invest urus right solid platform vetted 45 000 users supports orders routing 60 cex dex exchanges 25m marketcap urus undervalued urus aave comp orn eth',
#   'p sure u would never catch rene talking something embarrassing public',
#   'eyes qi',
#   'nu silence storm link sushi yfi sol aave ltc ankr knc kava xem band ren zec nav btc ada srm zen xrp xlm eth theta zil inj bzrx rune crv coti ftm dia ava bnb ksm',
#   'swing theta 4 98 trx 0 08792 xmr 248 9 cake 18 77 eos 3 86 xtz 5 90 aave 274 8 axs 76 73 atom 34 27 ftt 51 35 go',
#   'clv 1 buy imo btc eth mkr aave comp uni link xrp doge icp ect snx sol mln qnt farm yfi forth storj fil mana enj ogn bal nmr fet ach amp ankr zrx ren lrc skl celo rlc gtc matic grt luma wluna req poly iotx xyo',
#   'farm hit 200 thats approx 30 level today next week happen btc eth mkr aave comp uni link xrp doge icp ect snx sol mln qnt farm yfi forth storj fil mana enj ogn bal nmr fet ach amp ankr zrx ren lrc skl celo',
#   'faavebook twittaave',
#   'love appeared timeline followed',
#   'need cpap machine snoring cleared 20 men entire church retreat cabin',
#   'could earning 6 apr compounding interest dont sleep free aave',
#   'come said hello',
#   'lol surprise',
#   'dont miss next move hours trx eos shib aave cro bsv algo mkr fil luna ftt xtz btcb cake klay amp atom neo leo miota tfuel avax xmr chat r00m details b 0',
#   'see chatter fixed rate yields interest',
#   'yeah right lol',
#   'anyway congrats new role guardian pardon late say believe good chance better understand protocol',
#   'im also coffee shop entire team rents basement coffee shop across street talk social protocols every day owner coffee shop recently joined discussion',
#   'gb',
#   'swing theta 4 97 trx 0 08778 xmr 246 8 cake 18 85 eos 3 86 xtz 5 86 aave 274 2 axs 76 07 atom 34 34 ftt 51 23 go',
#   'interesting',
#   'luna mir anc ust btc rune atom ocean cake shib bnb axs matic link mine egld enj aave lota spec avax',
#   'luna mir anc ust btc rune atom ocean cake shib bnb axs matic link mine egld enj aave lota spec avax',
#   'gb',
#   'probably one best projects defi space utility token behind urus 25m right announcing big partnerships incredible terminal updates q4 urus aave comp orn eth',
#   'release time frame yet',
#   'im flattered',
#   'sounds like cool coffee shop',
#   'good thread actually dont remember saying anything institutional product tho 3',
#   'thread response one threads upcoming institutional product seem find thread giga brain give follow threads gold generally correct first one disagree 9 9',
#   'saying build walled garden nft airdrop morally consistent get one salty absolutely salty even one tiny bit salty 7',
#   'win 4 000 alpha yfi dip yield route idle aave rune dgcl ern super prt font bondly eth sol htr cell dot ksm ada atom ocean link dia band trb orai uni sushi zero win 1',
#   '',
#   '',
#   'boys preparing busy day across ecosystem including',
#   'plot twist dean table discussing table beside',
#   'okex users purchase crypto inr trading pairs including usdt aave matic etc access trading facilities available across exchanges',
#   'projects slowly becoming integral part crypto world nu ddx bond band link sushi yfi sol aave ltc ankr knc kava xem band ren zec nav btc ada xrp xlm eth bnb fida',
#   'swing theta 4 93 trx 0 08771 xmr 243 8 cake 18 71 eos 3 85 xtz 5 82 aave 273 8 axs 76 66 atom 34 1 ftt 51 48 go',
#   'yfi 28940 74 1 34 yfii 3962 04 1 17 mkr 2269 78 1 31 comp 294 81 11 22 aave 275 67 0 11 bal 19 63 0 3 dot 27 88 0 56 badger 15 59 1 93 ftt 52 23 2 23 uni 23 38 3 21 avax 66 05 0 53',
#   'doge shib yfi btc fil link uni eth xrp bch sushi bnb enj eos ygg aave dot cake bake sol axs',
#   '1 4m votes 800k votes galaxy brain blue chip ogs course theyre across project 99k votes 29k votes 21k votes 3k votes 41 300 votes nerrr',
#   'yuuuuuup',
#   'slp live die last chance survive btc xvg eth dot link hbar vet sushi crv tomo bnb dash ankr ltc xrp ont ada bch uni aave theta neo doge yfi ftt xlm zil sc mth rvn wpr storj icx shib axs',
#   'sounds like need new coffee shop',
#   'daily briefing september 30th getting apy apr 1 15 5 apy 2 15 1 apy 3 8 0 apy earn top projects today',
#   'coffee people talking new social network plans',
#   'aave aave sep 30 aave long new post link chart',
#   'aave aave sep 30 aave',
#   '30 september 21 crypto btc eth bnb ltc xtz axs omg iotx poly woo dent cvc hive maid etn fida cfg ddx xlm aave neo eos nmr',
#   'aave aave sep 30 aave read telegram',
#   'jar make everyone millionaire x1000 next week partnership mir xlm trx rsr sol mwc btc ada omg bnb flow link waves uni ltc doge btc sol ada aave vet xrp',
#   'swing theta 4 97 trx 0 08806 xmr 242 6 cake 18 89 eos 3 87 xtz 5 90 aave 276 1 axs 74 96 atom 34 44 ftt 52 35 go',
#   'top doge aave buyers told dead 1 btc 4 ltc less 220 0 02',
#   'top price gainers past hour top 100 market cap aave celo axs klay rev',
#   'add deposit collaterlization tokens market saw many simplicity aave provides litt',
#   'urus never fails amaze trx dot ada sol aave bsc urus luna egld quick',
#   'saala ek inning bhi khelta pichle saal playoffs mein hote chu ya',
#   'bnb simply touch green zone order got filled target 1 hit follow us update sand theta axs chz enj mana uni link aave amp comp',
#   'mkr aave dot 2m best trading indicator result 2 professional traders working hard 10 years create simple efficient system helping new experienced traders reading chart without extra useless noise',
#   'aave pump bcs comp news people redistributing imo',
#   'buy aave price 278 target 279 change 0 23 trading test 156',
#   'aave increased 3 62 5 7 hour price 280 30000000 usdt 06 34 55 utc',
#   'wanna make money follow xmr aave cake miota axs grt xtz cro algo neo klay btcb qnt bsv mkr egld ksm ftm btt waves hbar shib comp leo ht near dash rev amp rune',
#   'holders price back ersdl 13246 holders yesterday 13238 holders today 8 unersdl 2993 holders yesterday 2992 holders today 1 16 230 holders link luna eth btc albt aave',
#   'btc eth dot ksm avax sol luna aave xtz cake grt mkr comp perp ren bnt yfi sushi snx link bnb rune crv ltc mir polx kda rose matic tlos form srm rsr alpha xvs stx lyxe kda htr',
#   'swing theta 4 99 trx 0 08844 xmr 242 8 cake 19 09 eos 3 91 xtz 5 88 aave 277 2 axs 72 67 atom 34 51 ftt 52 23 go',
#   'devo dire che questo del buon uno dei migliori video esplicativi ed interessanti sulla visti di recente btc eth bnb dot sol matic avax algo ada luna comp uni sushi mkr cro aave quick ftm cake atom',
#   'hey send dm promotions 120k sub telegram channel full potential investors',
#   'aave currently oscillation structure waiting breakthrough choose direction try buy low sell high range volume pulling homeopathic intervention fall support leave field support 260 pressure 309',
#   'hive quick 10 profit target done hours forgot mentioned follow us update sand theta axs chz enj mana uni link aave amp comp',
#   'major achievement proven short triumphs one another believe aave platform implementation next catalyst prove brilliant technology amp teams business acumen defi context',
#   'ye tokan bad nhi rha h',
#   'swing theta 5 00 trx 0 08852 xmr 243 8 cake 19 16 eos 3 91 xtz 5 99 aave 277 8 axs 73 47 atom 34 93 ftt 52 29 go',
#   'snoring',
#   'ryiu uv mtn busd bnb usdt cake ptr matic ckb eth ankr albt nuls uma shib feg zil gmb dph vra rlc aave safe vrx kcs defi one doge ada uni oxt mkr comp avax knc icp grt yfd bepro yfi ryiu ptr link luna',
#   'sleeping giant',
#   'thought working lending borrowing nfts great folks like spent liquid crypto jpgs people lend nfts borrow crypto buy illiquid jpgs',
#   'aave esta en mi top 5 encanta tremendo valor si se retoman las subas esta es l der',
#   'mkr aave comp crv tremendos fundamentos en ofertas navide 60 pueden faltar hoy en en la cartera de la dama el bolsillo del caballero',
#   '',
#   'skl day fellas join party see 30 link btc eth nu algo grt mana ren band cvc dnt fil dash knc bnb oxt bat doge aave xtz xlm xrp zrx ada dot uni ren sushi enj maker atom ada skl matic',
#   'eventually allows xcad plugin run 50 quickly btc eth ada sol atom matic uni dot avax qnt kcs kava bch eos link zil vra ltc bnb neo axs xrp xtz theta enj trias ar vxv bat kda aave egld icp algo luna',
#   'prq parsiq announced pretty cool things besides iq protocol alts defi dot ltc eth bnb btc om rfuel ksm gvt sky xvg trx rsr link ada eos aave neo zil comp icx sol tomo kai pols',
#   'tambi n lleve aave',
#   'chinese traders going dexs like uni aave dydx decentralized require kyc china say whatever want stopped fight chinese people want',
#   'demand respect aave dare let fall number 40 market cap defi blue chip market gods owe pump team',
#   'airdrop giveaways aave compound ended',
#   'rektember ended uptober started btc eth usdt ada bnb xrp sol dot doge avax luna uni link ltc algo atom matic icp trx ftt vet xmr axs aave ftm ksm waves dydx',
#   'dont miss next move hours trx eos shib aave cro bsv algo mkr fil luna ftt xtz btcb cake klay amp atom neo leo miota tfuel avax xmr chat r00m details b 0',
#   'arent major defi projects etc already building dapps blockchain domain practical application blockchain domains building real life applications feasible yet',
#   'last time snatched bottom like orgy aave',
#   'new farms check aprs link aave lp join hottest yield farm matic',
#   'ftt bch aave subindo stoploss e diminuindo risco',
#   'swing theta 5 02 trx 0 08854 xmr 244 cake 19 22 eos 3 90 xtz 5 99 aave 277 8 axs 73 59 atom 35 17 ftt 52 31 go',
#   'mine buying ethlend back 2018 selling end 2018 loss yes aave yes high 6 figures range held 2021 yolo',
#   'omg much resistance ahead varna dex quasar fast exits month next icp etc people say omg btc eth xrp dot ada ltc bnb uni aave doge snx eos mkr atom xtz comp sushi sol luna zrx icp ftt fil',
#   'iotx run btc eth mkr aave comp uni link xrp doge icp ect snx sol mln nkn storj fil mana enj ogn bal nmr fet ach amp ankr zrx ren lrc skl celo nu xyo rly poly req luna wluna pla clv dnt cvc uma keep ctsi rep',
#   'congrats well deserved',
#   'strongest movers 1 zil 2 bnb 3 ohm 4 qtum strengthening 1 axs 2 flow 3 aave 4 ftm top coins',
#   'aave currently oscillation structure waiting breakthrough choose direction try buy low sell high volume pull homeopathic intervention falling support leave field support 260 pressure 309',
#   'top coins last hour qtum 9 86689 2 9057369 axs 73 57328 2 15809516 aave 279 34042 2 13743152 xtz 5 96863 2 10961918 celr 0 14885 1 95909208 trade ftx',
#   '',
#   'aave overbought high volume short signal success rate 69 52 187 269 average gain 1 81 chart period 30',
#   'aave usd looking 275 9130 264 7650 resistences 287 0610 314 9310 invalidation 250 8300 daily 20 trading test automation free',
#   'aave u got us favor tp 30 move sl let ride trading risk free best feeling ever',
#   'aave 5 minutes entry signal time 30 9 0 45 binance aaveusdt direction long tp price 277 7 pips points gained 8 1 move 3 subscribe trading signals',
#   'exchange top 5 bullish trend strength 1 zil 2 iotx 3 fil 4 omg 5 gvt top 5 bullish reversal strength 1 arpa 2 btcst 3 ark 4 lit 5 aave results free website',
#   'ask discord please',
#   'ksm aave luna looking good holding crossing fingers trend continues showing minor divergence watching break resistance red',
#   '14 17 ygg also deploys treasury invest portfolio assets generate yield according ygg core protocols include total amount locked yield farming standing usd 1 09million end july',
#   'farm get nice pop well buy btc eth mkr aave comp uni link xrp doge icp ect snx sol mln nkn storj fil mana enj ogn bal nmr fet ach amp ankr zrx ren lrc skl celo',
#   'aave losing 50w would painful',
#   'swapped 249k usdc aave 459k',
#   'swing theta 4 98 trx 0 08822 xmr 240 7 cake 19 eos 3 87 xtz 5 84 aave 273 7 axs 72 21 atom 34 84 ftt 51 66 go',
#   '2nd layers aave',
#   'nice see xpr list xpr proton lend coming soon looking like nov cross chain loaning loan gov token proton lend superior competitor aave amp lending platforms lend cryptos cross chain like proton lend',
#   'comp mismos fundamentos que aave mira ese grafico si pagan ahi entonces vayan compren bonos del tesoro americano',
#   'aave de esos tokens que ya ni miro el precio es long hodl',
#   'aave hoy genera mas guita x mes que en su ath hoy tiene mas tvl que en su ath constante desarrollo hace os su precio 60 desde su ath',
#   'nice ser',
#   'aave',
#   'sps dips buy going 10 following axs btc eth ada sol atom matic uni dot avax qnt kcs kava bch eos link zil vra ltc bnb neo xrp xtz theta enj trias ar vxv bat kda aave egld icp algo luna',
#   'avalanche rush bullish avax idk bullish aave seeing forest trees',
#   'potential player already exists eth link ohm aave rune clue',
#   'aave looks good daily definitely asset worth patience',
#   'buy aave price 274 target 275 change 0 18 trading test 161',
#   'takes 1 aave u reasonably financially free work hard find',
#   '1 aave potential every year find aave 2018 link 2020 lyxe 2021 ohm whats next aave 2022 search never stop',
#   'lately seeking momentum aave next trend',
#   'aave overbought short signal success rate 75 56 238 315 average gain 1 74 chart period 30',
#   'aave buy recommendation ignoring mid week blip price charts show steady downward trend hodl 2',
#   'swing theta 4 97 trx 0 08827 xmr 240 5 cake 18 93 eos 3 86 xtz 5 90 aave 273 axs 71 56 atom 34 7 ftt 51 65 go',
#   'theres vs us us unfortunate sure group need start running office instead demanding change touch geriatric career politicians theres way',
#   '',
#   'criptomoeda news xmr miota aave atom neo avax xtz ftt btt algo xem ksm egld mkr etc crv band comp chz bar psg enj mana snx forth vancat rlc icp',
#   'congrats coder dan worthy title man stature',
#   'joe grown x63 tweet youre still looking alpha follow umb ckb gala enj trac pols yldx bsv ogn ohm time hex zec etc omg sfp xcad aave ksm mrph doge uncx luna xtz vidt sps ftm xrp ar',
#   'come join team market updates trade signals pancake gems vip channel accurate trader tg ftt xlm trx etc vet theta xtz cake egld cro eos aave axs miota qnt near grt hbar shib',
#   'unwrap',
#   'place usdt wmatic unwrap wmatic matic',
#   'aave qui n conmigo aqu desde el streaming de esta ana activen la campanita joder',
#   'buy aave',
#   'zora building first financial nft marketplace release eom first mover advantage aave founder discord 7m marketcap 5 463 circulating supply 10k total dyor expecting blow october uni',
#   'way ahead yah',
#   'et sur one viite ils sont pas pr ts',
#   '',
#   '2021 09 28 15 00 gmt aave total trading volume 362 097aave price change 0 9 last 24 hrs aave',
#   'algo celo poof head explode much news across various chains algo celo poof aave mask',
#   'crypto traders want one thing disgusting link aave utk wan sol ksm dot',
#   'aave overbought high volume short signal success rate 69 4 186 268 average gain 1 82 chart period 30',
#   'coti dash lpt hbar ltc leo ncash farm xdc alpha ht btcb axs aave omg link matic rkt yfii ardr chz dag unfi dbc ont bplc fun xvg ksm mana cct bcd orn spy tct btcst sol amc sushi cpac eos fxs pltr',
#   'move 1 3 funds permanently',
#   'tide rising movr dag ltx xrp qnt sol matrix vxv aave ada link vet eth btc rsr dash hbar fet audio epik nano xdc ltx',
#   'jar land mars x8000 easy pump weekend buy 600k mc big partners dot fil etc ubt dot btc dcr rvn sol rev aave btc win matic sol btmx sol avax alpha btt hbar enj dydx',
#   'swing theta 4 94 trx 0 08815 xmr 240 4 cake 18 87 eos 3 85 xtz 5 92 aave 274 axs 72 6 atom 34 96 ftt 51 6 go',
# ...
#   'swing flow 5 96 mkr 2 041 00 waves 18 55 one 0 15 cake 6 54 zec 128 40 aave 128 60 btt 0 00 rune 5 32 grt 0 36',
#   'apps new loan officers',
#   'egld aave',
#   'works fine correct gas usage around 40 average attached rpc',
#   'hot futures aave 129 80',
#   'yfi 21711 88 3 04 yfii 2088 88 2 14 mkr 2038 88 2 65 comp 116 94 3 36 aave 129 62 5 38 bal 12 35 5 37 dot 18 0 3 27 badger 8 61 4 02 ftt 44 85 2 94 uni 9 54 5 06 avax 78 14 6 4 usdt 1 0001 0 02',
#   'low rsi coins report low rsi 1h dusk uni rsr reef bal gala low rsi 4h blz rsr aave reef snx algo low rsi 1d api3 imx ray flow rsr sushi',
#   'cheap coins report cheap 1h xmr dusk gala ksm bal reef cheap 4h gtc lpt arpa sc uni bal cheap 1d klay blz algo aave reef rsr',
#   '',
#   'bank come defi pandoras box open',
#   'hot futures ltc 111 30 aave 129 70 yfi 21 638 88',
#   'bollinger bands fakeouts daily btc pairs aave cnd mth nav yoyo',
#   'hot futures avax 79 13 ltc 111 60 aave 130 40 yfi 21 703 17',
#   'swing flow 6 09 mkr 2 045 00 waves 18 43 one 0 15 cake 6 58 zec 129 40 aave 130 40 btt 0 00 rune 5 34 grt 0 37',
#   'trade slowly surely expected pump buy em atom btc eth bnb yfi qnt qi looks rare ern aave audio cell',
#   'trade slowly surely expected pump buy em atom btc eth bnb yfi qnt qi looks rare ern aave audio cell',
#   'renounce ownership folks make sure devs renounce ownership doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'central bank brazil chosen nine partners help develop digital real brazils central bank digital currency cbdc among partners crypto exchange decentralized finance defi platform details',
#   'called dump every one short profit join g chenel free hyve apl play play iost oxen pundix tko tko band aave eqx bsv mln tko',
#   'crypto traders want one thing disgusting link aave utk wan sol ksm dot',
#   'low rsi coins report low rsi 1h dusk uni rsr reef gala bts low rsi 4h blz aave rsr reef snx hnt low rsi 1d api3 imx ray flow rsr sushi',
#   'cheap coins report cheap 1h xmr gala dot reef ksm dash cheap 4h arpa dash gtc uni sc lpt cheap 1d klay blz aave reef trx rsr',
#   'perfect slowly surely proposed add floki since insane community increase adoption great marketing great utility great',
#   'make hit 1000 first egld sol avax aave',
#   '120 verdes un aave rame liquidez meu dios',
#   'facts doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'mercado shitcoin',
#   'aave really want make huge profits trading check chat',
#   'lie dumb fux find patsy billionaires im still dat sh remembered doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'swing waves 18 71 mkr 2 059 00 flow 6 09 one 0 15 cake 6 60 aave 130 30 btt 0 00 zec 128 40 rune 5 35 grt 0 37',
#   'also go check guy original creativity btc eth ltc atom link xtz xlm grt dash oxt xrp cvc ocean alpha knc ren aave fil bnt doge nu bat dnt algo bnb band shib trac link xtz xlm grt dash oxt',
#   'crypto u think 10x year btc qsp xrp xtz ada knc grt skl dash aave ankr eth amp atom mana storj ren shib icp xyo doge ltc cro zec enj mkr cvc mdt snx mln fet yfi link matic suku iotx gala avax loom quick track ctsi sol',
#   'spell breakout coming btc eth ltc atom link xtz xlm grt dash oxt xrp cvc ocean alpha knc ren aave fil bnt doge nu bat dnt algo bnb band shib trac link xtz xlm grt dash oxt',
#   'safe assume waiting press release name picture patsy doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   '',
#   'cant make stuff bye doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'home address pictures relatives passport info friends phone numbers log bank records 60 seconds doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'brezilya merkez bankas merkez bankas dijital para birimi olan dijital realin geli tirilmesine katk da bulunmak brezilya kripto borsas mercado bitcoin santander brasil ita unibanco bankalar def protokol aave aave ile ortakl k amas nda',
#   'criptomonedas perdedoras cbg chainbing 11 52 usd 38 27 cvx convex finance 9 45 usd 19 83 one harmony 7 8 usd 0 15 aave aave 6 93 usd 129 52 crv curve dao token 6 86 usd 2 5',
#   'aaveusdt 498 67 aave traded vwap 129 822 last 10 seconds 13 08 stdevs mean buys 498 67 sells 0 00',
#   'crime pick hobby something doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'look find patsy return liquidity save project everyone connected gone like bye bye doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'low rsi coins report low rsi 1h dusk uni arpa reef bts eth low rsi 4h blz aave rsr snx reef hnt low rsi 1d api3 imx ray flow rsr sushi',
#   'cheap coins report cheap 1h dot xmr arpa dash reef uni cheap 4h dash lpt arpa gtc sc uni cheap 1d klay blz trx aave algo reef',
#   'know f cked right doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'bruh see everything ledger using tools doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'havent moved money doesnt mean youre going prison doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'goat',
#   'huge',
#   'maybe',
#   'look',
#   'weak structuring weak chain hopping transactions big matter time youre gone doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'looks like near gonna main gainer year promising interest btc icx aave sol eth vet matic link xlm dot doge uni cake ksm bnb ava luna omg iotx ava osmo scrt juno cro xrp pha ada avax atom trx xno ada torn omm high neo',
#   '',
#   'swing mkr 2 042 00 waves 18 66 flow 5 95 cake 6 53 one 0 15 zec 125 30 aave 128 60 rune 5 22 btt 0 00 grt 0 36',
#   'ill find point personal doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'still got list might one bad actor might outsourced group access doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'worst price drops day nu 11 85 rndr 7 99 zrx 7 95 one 7 72 dydx 7 72 cvx 7 35 ftm 7 28 aave 6 92 poly 6 62 skl 6 35 rose 6 32 gno 6 3 woo 6 14 avax 6 03 elon 6 03 sol 5 96',
#   'probably best crypto community btc celr mkr yfi sushi dydx uni perp crv atom comp aave',
#   'thank mentor xeus',
#   'probably best crypto community btc celr mkr yfi sushi dydx uni perp crv atom comp aave',
#   'novice made lot mistakes came know c0mmunity shib aave cro bsv algo mkr fil luna',
#   'says eth look wallet os amount weth polygon chain inside mm wallet seem legit',
#   'huge coti orn aave',
#   'pretty sure 100 shows eth',
#   'aave really want make huge profits trading check chat',
#   'make sale opensea polygon network would show weth polygon chain metamask im trying make sure ive scammed haha',
#   'new episode defi lunch ep 96 march 3 2022 dump tracking rose stable yields matic steth joe cawley brad nickel c player links amp show notes',
#   'probably best crypto community btc celr mkr yfi sushi dydx uni perp crv atom comp aave',
#   'best',
#   'cont congrats 1bn fund amp named 2022 room everyone ship grab seat wherever feel comfortable',
#   'cheap coins report cheap 1h xmr dot dash reef zrx egld cheap 4h dash lpt sc gtc rose srm cheap 1d klay blz trx aave snx algo',
#   'low rsi coins report low rsi 1h dusk uni sc reef zrx rsr low rsi 4h blz aave rsr snx hnt zrx low rsi 1d api3 imx flow ray rsr sushi',
#   'deposit save earn interest forget bit',
#   'aave kda',
#   '24 hours top losers harmony one 0 1526 8 53 198 761 767 fantom ftm 1 85 8 47 1 616 222 028 curve dao token crv 2 49 8 05 259 603 482 aave aave 128 59 7 94 209 656 776 flow flow 5 98 7 14 89 992 163',
#   'swing flow 5 98 mkr 2 050 00 waves 18 56 one 0 15 cake 6 54 rune 5 29 zec 127 20 aave 128 20 btt 0 00 grt 0 35',
#   '2022 03 03 14 00 gmt aave price change 4 7 total trading volume 381 011aave last 24 hrs aave',
#   'novice made lot mistakes came know c0mmunity shib aave cro bsv algo mkr fil luna',
#   'huge',
#   'app server appears',
#   'aave really want make huge profits trading check chat',
#   'book dope cover daf doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'institutional arm aave biggest bag',
#   'yfi 21504 89 0 08 yfii 2062 23 2 67 mkr 2022 64 1 54 comp 117 45 2 51 aave 128 47 6 87 bal 12 38 4 81 dot 18 02 2 81 badger 8 4 6 9 ftt 44 3 3 49 uni 9 5 5 3 avax 78 07 6 14 usdt 1 0002 0 01',
#   'country war sh excuse scamming people cut sh doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'interesting watch defi cefi relationship evolve currently ranked 66th mc whenever sector rebound comes aave well',
#   'aaveusdt 469 82 aave traded vwap 128 598 last 10 seconds 14 13 stdevs mean buys 469 82 sells 0 00',
#   'low rsi coins report low rsi 1h dusk rsr uni sc blz dgb low rsi 4h blz rsr aave 1000bttc snx hnt low rsi 1d api3 imx ray flow rsr sushi',
#   '1b bear cryptos last 24 hours symbol cbg 12 0 39 0786 one 8 07 0 1520 cvx 7 55 19 6859 ftm 7 42 1 84311 aave 6 69 128 590 avax 6 08 78 0780',
#   'cheap coins report cheap 1h unfi dash uni bts xmr ksm cheap 4h srm xrp hbar uni sc hnt cheap 1d klay blz trx aave imx rsr',
#   '',
#   'great orn team keep delivered',
#   'users bridge orn eth usdc usdt ftm link matic comp shib inch uni sushi coti aave networks week adding new assets secure bridge market chains coming',
#   'coti aave listed coti aave available first p2p atomic swap cross chain bridge l1 l1 delays exploits secure bridge orn',
#   'orn coti aave added orion bridge orn coti aave',
#   'get cant think better man job needful sir',
#   'btc fire eth shib doge matic link luna lou ltc bch aave',
#   'se ilen ortaklar aras nda nde gelen brezilya kripto borsas unibanco bankalar protokol aave aave yer almaktad r',
#   'futures aaveusdt 2 935 1 aave traded vwap 128 0343 last 10 seconds 18 13 stdevs mean buys 1 215 9 sells 1 719 2',
#   'central bank brazil selected nine partners assist creation digital real including local crypto exchange defi protocol reports',
#   'aaveusdt 479 12 aave traded vwap 128 026 last 10 seconds 16 96 stdevs mean buys 207 70 sells 271 42',
#   'swing waves 18 16 flow 6 03 mkr 2 031 00 one 0 15 cake 6 57 rune 5 44 aave 129 00 btt 0 00 zec 127 10 grt 0 36',
#   'spirit satoshi dont want know developed 3rd party shit im using known strong armed compliance',
#   'central bank brazil selected nine partners assist creation digital real including local crypto exchange defi protocol reports',
#   'aave brewing new ath follow ont rot usdc hnt vgx chsb mas rune ame bat dft bnfy',
#   'ada fun hard next month follow link sushi yfi sol aave ltc ankr knc kava xem band',
#   'im working new ramps report ledger im done im coming doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'wen chainlink wallet',
#   'novice made lot mistakes came know c0mmunity shib aave cro bsv algo mkr fil luna',
#   'deposits',
#   'criptomonedas perdedoras cbg chainbing 10 07 usd 39 81 one harmony 7 45 usd 0 15 cvx convex finance 7 26 usd 19 82 aave aave 6 27 usd 128 77 ftm fantom 6 22 usd 1 86',
#   'btc highway control ramps want shut exchanges doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'aave really want make huge profits trading check chat',
#   'aave traded token 1000 biggest wallets past 24hrs top 1000 whales hodling 437 620 worths 62 161 344 whale leaderboard',
#   'sell aave 128 9 1 45',
#   'hi',
#   'tons better lending platforms dont anything special',
#   'promise world one big movie script youre movie know ends doge aave etc ada matic xtz mana eth btc bnb comp enj storj shib algo sol rvn nvda tsla gme amc ashib luckydragon metapay shibt',
#   'keep keeping btc eth link ltc dash nano vet vtho one ont fil bal nu aave oxt',
#   'icymi index coop named 2022 list innovative blockchain startups along amp',
#   'also love spent money voting protocol improvements bags consistently going hell',
#   'estamos empolgados e satisfeitos com certeza de que estamos construindo nova economia digital com um time super competente e engajado caminho para consolida dessa nova economia vai sendo trilhado pela nossa nave toda velocidade vamos juntos',
#   'hater love aave bag hold long losses without hope',
#   'censorship resistance goes hands rpc education people know care set alternative rpcs wallets cant shit',
#   'ignore guys complete hater focuses price sure hurt',
#   'unroll',
#   'aave aave price idr rp 1 837 339 price usd us 127 9 high usd us 139 56 low usd us 127 6 change 1 h 0 1 change 24 h 7 play earn p2e nft happy 3rd',
#   'novice made lot mistakes came know c0mmunity shib aave cro bsv algo mkr fil luna',
#   '',
#   '',
#   'swing waves 18 83 flow 5 96 mkr 2 001 00 one 0 15 cake 6 55 rune 5 28 btt 0 00 aave 127 70 zec 123 00 grt 0 36',
#   'aave real price come soon follow price target',
#   'correct twitter handle account suspended rekt',
#   'top gainers 1 anc 16 96 2 qnt 9 7 3 okb 6 1 biggest losers 1 aave 9 87 2 avax 8 7 3 ftm 8 43 market weak',
#   'talk aave investement price original tweet answer aave provides provide ecosystem thats',
#   'finally achieved wanted pltr mkr iost btt aave mana ksp dnt dydx',
#   '6 looked launch v3 expansion new chains includes analysis new features portals high efficiency mode isolation mode aave need continue innovating rapidly',
#   'novice made lot mistakes came know c0mmunity shib aave cro bsv algo mkr fil luna',
#   'aave really want make huge profits trading check chat',
#   'aave brewing new ath ont rot usdc hnt vgx chsb mas rune ame bat dft bnfy',
#   '',
#   'lending protocols like serve primitives utilized developers spin lending functionalities users always exposed risk entire platform',
#   'btc eth bnb xrp luns ada sol avax dot doge shib matic cro atom ltc link uni ftt trx bch leo algo mana xlm ftm hbar ico etc sand fil axs vet theta klay xmr xtz hnt eos flow aave waves mkr one btt cake gala grt neo kcs zec',
#   'mana xlm ftm hbar ico etc sand fil axs vet theta klay xmr xtz hnt eos flow aave waves mkr one btt cake gala grt neo kcs zec stx',
#   'eos flow aave waves mkr one btt cake gala grt neo kcs zec stx',
#   'short usd total group raining gem tokens grab entries asap going moon go check tct dock yfii bal yfi cfx badger crv aave vite polc mir mtl',
#   'hnt eos flow aave waves mkr one btt cake gala grt neo kcs zec stx',
#   'aave aave price idr rp 1 843 163 price usd us 128 25 high usd us 139 56 low usd us 127 6 change 1 h 0 3 change 24 h 7 5 play game earn eth tomorrow x together',
#   'fil axs vet theta klay xmr xtz hnt eos flow aave waves mkr one btt cake gala grt neo kcs zec stx',
#   '',
#   'ps pleb',
#   'almost 2 years aave still unable find utility token sustain protocol plebs holding voting someday somehow nobody knows valuable titanic protocol save crypto looks funny',
#   'ada fun hard next month link sushi yfi sol aave ltc ankr knc kava xem band',
#   'aave hilariously oversold tweet',
#   'low rsi coins report low rsi 1h aave dusk snx rsr flow blz low rsi 4h blz aave rsr snx hnt klay low rsi 1d api3 imx flow ray rsr sushi',
#   'aave watch bounce baby said bottomed decimal go 12 mil total less btc',
#   ...]}

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\yanwe\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
## VADER testing and understanding

testText = "Railgun Ð·Ð°ÐºÐ»ÑŽÑ‡Ð°ÐµÑ‚ ÑÑ‚Ñ€Ð°Ñ‚ÐµÐ³Ð¸Ñ‡ÐµÑÐºÐ¾Ðµ Ð¿Ð°Ñ€Ñ‚Ð½ÐµÑ€ÑÑ‚Ð²Ð¾ Ñ Digital Currency Group Ð¸ Ð¿Ð¾Ð»ÑƒÑ‡Ð°ÐµÑ‚ Ñ„Ð¸Ð½Ð°Ð½ÑÐ¸Ñ€Ð¾Ð²Ð°Ð½Ð¸Ðµ Ð² Ñ€Ð°Ð·Ð¼ÐµÑ€Ðµ $10ÐºÐº. #crypto #defi #privacy"
negativeTest = sid.polarity_scores(testText)

testText = "market doing well go up"
positiveTest = sid.polarity_scores(testText)
## compound can be use to net the sentiment.. negative mean bear

print(negativeTest)
print(positiveTest)
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.2732}

# %%
## Geting Sentiment Score using VANDER's sentiment model
for month in timeSplitData:
    for content in timeSplitData[month]:
        output = sid.polarity_scores(content)
        timeSplitDataSentiment[month].append(output)

# %%
## Calculating Net Weighted Sentiment Score
timeSplitDataNetScore = {}
for month in monthList:
    timeSplitDataNetScore[month] = 0 
    
for month in timeSplitDataSentiment:
    for output in timeSplitDataSentiment[month]:
        compound = output['compound']
        compound = compound / len(timeSplitDataSentiment[month])
        timeSplitDataNetScore[month] +=compound

# %%
timeSplitDataNetScore
# Out:
# {'09/2021': 0.17964456187213187,
#  '10/2021': 0.19785781279398212,
#  '11/2021': 0.21130531920733392,
#  '12/2021': 0.17947591531455456,
#  '01/2022': 0.18357598263521835,
#  '02/2022': 0.1976905354084466,
#  '03/2022': 0.15884808861859254}

# %%
import matplotlib.pyplot as plt

xAxis = []
yAxis = []

for date in timeSplitDataNetScore:
    xAxis.append(date)
    yAxis.append(timeSplitDataNetScore[date])

plt.plot(xAxis,yAxis, color='red', marker='o')
plt.title('Twitter AAVE CryptoCurrency Sentimental Analysis')
plt.xlabel('Month')
plt.xticks(rotation=45)
plt.ylabel('Net Sentiment')
# plt.grid(True)
plt.show()
