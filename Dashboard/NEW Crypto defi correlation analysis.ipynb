# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

aave = pd.read_csv('aave_price_data.csv')
compound = pd.read_csv('compound_price_data.csv')
curve = pd.read_csv('curve_price_data.csv')
maker = pd.read_csv('maker_price_data.csv')
sushi = pd.read_csv('sushi_price_data.csv')
uniswap = pd.read_csv('uniswap_price_data.csv')

# %%
d = {'aave':aave['Price'],'compound':compound['Price'],'curve':curve['Price'],'maker':maker['Price'],'sushi':sushi['Price'],'uniswap':uniswap['Price']}
df = pd.DataFrame(data=d)
df
# Out:
#        aave  compound   curve     maker  sushi  uniswap
# 0    123.40     101.4  1.9849  2,334.10  2.883     8.32
# 1    116.60     101.1  2.0595  2,395.60  2.904     8.48
# 2    124.60     109.7  2.2456  2,357.60  3.101     9.02
# 3    124.20     108.6  2.2495  2,492.10  3.042     8.79
# 4    129.99     117.4  2.5063  2,684.50  3.311     9.55
# ..      ...       ...     ...       ...    ...      ...
# 360     NaN       NaN     NaN    764.30    NaN      NaN
# 361     NaN       NaN     NaN    687.40    NaN      NaN
# 362     NaN       NaN     NaN    675.70    NaN      NaN
# 363     NaN       NaN     NaN    609.00    NaN      NaN
# 364     NaN       NaN     NaN    581.00    NaN      NaN
#
# [365 rows x 6 columns]

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                eth      aave    convex  compound   uniswap     maker
# eth       1.000000 -0.006561  0.804523 -0.307922  0.240881  0.118838
# aave     -0.006561  1.000000 -0.341618  0.860271  0.901807  0.755502
# convex    0.804523 -0.341618  1.000000 -0.614556 -0.191325 -0.169694
# compound -0.307922  0.860271 -0.614556  1.000000  0.670223  0.651603
# uniswap   0.240881  0.901807 -0.191325  0.670223  1.000000  0.689293
# maker     0.118838  0.755502 -0.169694  0.651603  0.689293  1.000000

# %%
channelList= [
    ['SushiSwap Community','Price Talk','749777962995548210'],
    ['SushiSwap Community','sushi-dao','748033004323995680'],
    ['SushiSwap Community','General','748031363935895556'],
    ['Compound','compound','402910780670083094'],
    ['Compound','ecosystem','600821861000937476'],
    ['Curve Finance','general','729808685009731610'],
    ['Curve Finance','curve-v2','852398327341514792'],
    ['Uniswap','general','597638926152499206'],
    ['Uniswap','speculation','756005648113860668'],   
]
